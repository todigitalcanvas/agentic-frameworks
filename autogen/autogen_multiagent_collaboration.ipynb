# %% [markdown]
# #### AutoGen workflow for collaborative research and review, use internet search tools, collaborate in a round-robin fashion, and produce a consolidated Markdown report

# %%
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_core import CancellationToken
from autogen_ext.models.openai import OpenAIChatCompletionClient    
from autogen_ext.models.ollama import OllamaChatCompletionClient
from autogen_ext.tools.langchain import LangChainToolAdapter
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain.agents import Tool
from dotenv import load_dotenv
from autogen_agentchat.messages import TextMessage

# %%
# This script demonstrates a multi-agent AutoGen workflow for collaborative research and review.
# Agents use internet search tools, collaborate in a round-robin fashion, and produce a consolidated Markdown report

# %%
load_dotenv()
# Out:
# True

# %%
# Helper function to set up and return a list of tools for the agents
def get_tools():
    # Internet search tool (Google Serper via LangChain)
    serper = GoogleSerperAPIWrapper()
    langchain_serper = Tool(name="internet_search", func=serper.run, description="Tool for searching on internet")
    autogen_serper = LangChainToolAdapter(langchain_serper)  # Adapter for AutoGen
    autogen_tools = [autogen_serper]
    
    return autogen_tools

# Helper function to get a model client for the agent (OpenAI or Ollama)
def get_model_client(model_name: str):
    if model_name == "gpt":
        return OpenAIChatCompletionClient(model="gpt-4o-mini")  # Use OpenAI GPT model
    elif model_name == "llama":
        return OllamaChatCompletionClient(model="llama3.2:1b")  # Use local Ollama Llama model

# %%
user_message="Write a short biography of Mahatma Gandhi"

# %%
## send message and run the multi-agent workflow

autogen_tools = get_tools()  # Get the list of tools (search)
model_client = get_model_client("gpt")  # Choose the model client

# Create the Researcher agent with internet search tool and detailed system prompt
researcher_agent = AssistantAgent(name="researcher", 
                   model_client=model_client, 
                   tools=autogen_tools, 
                   system_message="""
                   You are the Researcher Agent, responsible for gathering accurate and relevant historical information and biographical data about famous individuals using internet sources. Your tasks include:
                    - Searching the Internet: Use up-to-date and reliable sources to collect detailed and factual information about historical events, time periods, cultural movements, and well-known figures from various domains (e.g., politics, science, arts).
                    - Reporting Findings: Present the information in a structured, clear, and concise format. Prioritize relevance, factual accuracy, and source credibility.
                    - Collaborating with Reviewer Agent: After submitting your findings, await and incorporate feedback from the Reviewer Agent. Revise and refine your outputs based on their comments to improve quality, clarity, and completeness.
                    - Always cite or reference the sources of your information when applicable. Maintain a neutral, objective tone and avoid speculation unless clearly marked as such. Your goal is to support historical accuracy and biographical integrity through diligent research and iterative improvement.
                   """
                  )
# Create the Reviewer agent with a system prompt for critical review and feedback
reviewer_agent = AssistantAgent(name="reviewer", 
                   model_client=model_client, 
                   system_message="""
                   You are the Reviewer Agent, responsible for evaluating and refining the historical and biographical research conducted by the Researcher Agent. Your tasks include:
                   - Reviewing Findings: Critically examine the content provided by the Researcher Agent for:
                   - Factual accuracy
                   - Clarity and coherence
                   - Relevance to the topic
                   - Proper sourcing and attribution
                   - Providing Constructive Feedback: Suggest specific improvements, corrections, or additions to ensure the information is comprehensive, well-organized, and trustworthy. Maintain a collaborative and objective tone.
                   - Approving Final Output: Once all your feedback has been properly incorporated and the result meets quality standards, respond with "APPROVE" to finalize the research and terminate the collaboration.
                   - You play a critical role in ensuring the accuracy, completeness, and reliability of the information before it is considered final. Be thorough, but efficient.
                   """
                  )

# Add consolidator agent to summarize and format the conversation as Markdown
consolidator_agent = AssistantAgent(
    name="consolidator",
    model_client=model_client,
    system_message="""
    You are the Consolidator Agent. Your job is to take the entire conversation between the Researcher and Reviewer agents, and produce a well-formatted Markdown (.md) document that summarizes the research process and presents the final approved content. Structure the document with clear sections, such as Introduction, Research Process, Feedback & Revisions, and Final Output. Use Markdown formatting for headings, lists, and emphasis. Output only the Markdown content.
    """
)

# Set up a round-robin group chat with a termination condition ("APPROVE")
text_termination = TextMentionTermination("APPROVE")
team = RoundRobinGroupChat([researcher_agent, reviewer_agent], termination_condition=text_termination, max_turns=5)
result = await team.run(task=user_message)

# Write the conversation to a log file
with open("conversation_log.txt", "w", encoding="utf-8") as f:
    for message in result.messages:
        f.write(f"{message.source}:\t{message.content}\n\n")
        print(f"{message.source}:\t{message.content}\n")

# After approval, consolidate and write markdown file
# Prepare the conversation as a string for the consolidator
conversation_text = "\n".join([
    f"{message.source}: {message.content}" for message in result.messages
])

# Ask the consolidator to format the conversation as markdown
message = TextMessage(content=f"""Consolidate the following conversation into a well-structured Markdown file as described in your instructions.
                              Conversation is between two AI agents: Researcher and Reviewer. 
                              Consolidator is responsible for taking the entire conversation between the Researcher and Reviewer agents, and produce a well-formatted Markdown (.md) document that summarizes the research process and presents the final approved content. Structure the document with clear sections, such as Introduction, Research Process, Feedback & Revisions, and Final Output. Use Markdown formatting for headings, lists, and emphasis. Output only the Markdown content.
                             
                              Below is Conversation:
                              {conversation_text}""", 
                              source="user")
consolidation = await consolidator_agent.on_messages(
    [message], cancellation_token=CancellationToken()
)

print(consolidation.chat_message.content)
with open("final_output.md", "w", encoding="utf-8") as f:
    f.write(consolidation.chat_message.content)
# Out:
# user:	Write a short biography of Mahatma Gandhi
#
# researcher:	[FunctionCall(id='call_XR5xU96ghn1eQYPCn9g4qf9D', arguments='{"query":"Mahatma Gandhi biography"}', name='internet_search')]
#
# researcher:	[FunctionExecutionResult(content="Mahatma Gandhi (1869–1948) was an Indian lawyer, politician, social activist, and writer who became the leader of the Indian Independence Movement against ... Mohandas Karamchand Gandhi (2 October 1869 – 30 January 1948) was an Indian lawyer, anti-colonial nationalist, and political ethicist who employed ... Born in Porbandar, India, Gandhi studied law and organized boycotts against British institutions in peaceful forms of civil disobedience. He was ... Gandhi (1869-1948) was a lawyer and the prominent figure behind India's push for independence from British rule. He followed the philosophies of pacifism, ... Mohandas Karamchand Gandhi was leader of India's nonviolent independence movement against British rule. He was revered the world over for ... The first edition of Gandhiji's Autobiography was published in two volumes. Vol. I in 1927 and Vol. II in 1929. The original in Gujarati which was priced at. Monhandas Karamchand Gandhi was born in the small town of Porbandar, on the west coast of India, on October 2 1869. He belonged by birth to the Vaishya, ... Mohandas Karamchand Gandhi was born on October 2, 1869 in Porbandar, India. He became one of the most respected spiritual and political leaders of the 1900's. This is a biography of Mahatma Gandhi (1869-1948). He led the fight for Indian independence from British rule, who tirelessly pursued a strategy of passive ... The son of a senior government official, Gandhi was born and raised in a Hindu Bania community in coastal Gujarat, and trained in law in London. Gandhi became ...", name='internet_search', call_id='call_XR5xU96ghn1eQYPCn9g4qf9D', is_error=False)]
#
# researcher:	Mahatma Gandhi (1869–1948) was an Indian lawyer, politician, social activist, and writer who became the leader of the Indian Independence Movement against ... Mohandas Karamchand Gandhi (2 October 1869 – 30 January 1948) was an Indian lawyer, anti-colonial nationalist, and political ethicist who employed ... Born in Porbandar, India, Gandhi studied law and organized boycotts against British institutions in peaceful forms of civil disobedience. He was ... Gandhi (1869-1948) was a lawyer and the prominent figure behind India's push for independence from British rule. He followed the philosophies of pacifism, ... Mohandas Karamchand Gandhi was leader of India's nonviolent independence movement against British rule. He was revered the world over for ... The first edition of Gandhiji's Autobiography was published in two volumes. Vol. I in 1927 and Vol. II in 1929. The original in Gujarati which was priced at. Monhandas Karamchand Gandhi was born in the small town of Porbandar, on the west coast of India, on October 2 1869. He belonged by birth to the Vaishya, ... Mohandas Karamchand Gandhi was born on October 2, 1869 in Porbandar, India. He became one of the most respected spiritual and political leaders of the 1900's. This is a biography of Mahatma Gandhi (1869-1948). He led the fight for Indian independence from British rule, who tirelessly pursued a strategy of passive ... The son of a senior government official, Gandhi was born and raised in a Hindu Bania community in coastal Gujarat, and trained in law in London. Gandhi became ...
#
# reviewer:	**Review of Findings:**
#
# 1. **Factual Accuracy:**
#    - The biography accurately presents Gandhi's full name (Mohandas Karamchand Gandhi), birth date (October 2, 1869), and death date (January 30, 1948).
#    - Details about his role in the Indian Independence Movement, his background, and his philosophical approach to non-violence and civil disobedience are correctly mentioned.
#
# 2. **Clarity and Coherence:**
#    - The current structure appears fragmented, with sentences repeating information and lacking a coherent flow. This makes it difficult to read and absorb the information efficiently.
#
# 3. **Relevance to the Topic:**
#    - While relevant information is included, some sentences feel redundant and could be streamlined to improve focus.
#
# 4. **Proper Sourcing and Attribution:**
#    - The content lacks citations or references to reliable sources or primary texts, which is crucial in historical biographies.
#
# **Constructive Feedback:**
# - **Organization:** Structure the biography into distinct sections, such as Early Life, Career, Philosophies, and Legacy. This will help make the information more digestible.
#
# - **Redundancies:** Remove repetitive statements about his role as a leader and his approach to independence. Consolidate similar ideas.
#
# - **Sourcing:** Include references to Gandhi’s own writings, historical texts, or recognized biographies for credibility. For example, cite his autobiography or notable biographies written by acknowledged historians.
#
# - **Expansion:** Provide more details on key events he led (e.g., the Salt March, Quit India Movement) and elaborate on his philosophies, including terms like "Satyagraha." Mention significant aspects of his influence on global civil rights movements.
#
# **Revised Biography Suggestion:**
#
# Mahatma Gandhi, born Mohandas Karamchand Gandhi on October 2, 1869, in Porbandar, India, was a key figure in the Indian independence movement against British colonial rule. As the son of a senior government official in a Hindu Bania community, he pursued law studies in London, where his political and ethical philosophies began to take shape.
#
# Upon returning to India, Gandhi advocated for nonviolent resistance and civil disobedience, developing the concept of *Satyagraha*, which emphasizes truth and nonviolence as weapons against oppression. His leadership in significant events such as the Salt March in 1930 galvanized public support and drew international attention to India's struggle for independence.
#
# Gandhi's commitment to pacifism and social reform also addressed issues of inequality and communal harmony, influencing civil rights movements worldwide. He was revered not only in India but also around the globe for his unwavering commitment to justice through nonviolent means. Tragically, his life was cut short when he was assassinated on January 30, 1948.
#
# His legacy continues to inspire advocates for peace and social justice today, making him a symbol of nonviolent resistance and moral leadership.
#
# **Next Steps:**
# - Please refine the biography based on the feedback and make necessary changes. After confirming the adjustments, I will re-evaluate the final output for approval.
#
# researcher:	[FunctionCall(id='call_Md7VmDz0JRsOvraw3KUAkJjI', arguments='{"query":"Mahatma Gandhi autobiography and influences on civil rights"}', name='internet_search')]
#
# researcher:	[FunctionExecutionResult(content="Gandhi influenced the leadership of the civil rights movement including Ralph Abernathy, James Baldwin. Marian Wright Edelman, James Farmer, Martin Luther King, ... Mahatma Gandhi (1869–1948) was an Indian lawyer, politician, social activist, and writer who became the leader of the Indian Independence Movement against ... Gandhi protested against racism in South Africa and colonial rule in India using nonviolent resistance. A testament to the revolutionary power of nonviolence, ... His philosophy and leadership helped India gain independence and inspired movements for civil rights and freedom all across the world. The Story of My ... He inspired movements for civil rights and freedom across the world. The honorific Mahātmā (from Sanskrit, meaning great-souled, or venerable), first applied to ... Furthermore, Gandhi's teachings of inclusivity and equality influenced the Civil Rights Movement's focus on integration and equal rights for all ... Missing: autobiography | Show results with:autobiography. His methods of civil disobedience, namely his advocacy of nonviolent protest, influenced a number of later civil rights activists from around the world, ... Mohandas Karamchand Gandhi was leader of India's nonviolent independence movement against British rule. He was revered the world over for ... Gandhi adopted the term “civil disobedience” to describe his strategy of non-violently refusing to cooperate with injustice. Gandhi is, therefore, now a source of inspiration and a reference book for all those fighting against racial discrimination, oppression, domination, wars, ...", name='internet_search', call_id='call_Md7VmDz0JRsOvraw3KUAkJjI', is_error=False)]
#
# researcher:	Gandhi influenced the leadership of the civil rights movement including Ralph Abernathy, James Baldwin. Marian Wright Edelman, James Farmer, Martin Luther King, ... Mahatma Gandhi (1869–1948) was an Indian lawyer, politician, social activist, and writer who became the leader of the Indian Independence Movement against ... Gandhi protested against racism in South Africa and colonial rule in India using nonviolent resistance. A testament to the revolutionary power of nonviolence, ... His philosophy and leadership helped India gain independence and inspired movements for civil rights and freedom all across the world. The Story of My ... He inspired movements for civil rights and freedom across the world. The honorific Mahātmā (from Sanskrit, meaning great-souled, or venerable), first applied to ... Furthermore, Gandhi's teachings of inclusivity and equality influenced the Civil Rights Movement's focus on integration and equal rights for all ... Missing: autobiography | Show results with:autobiography. His methods of civil disobedience, namely his advocacy of nonviolent protest, influenced a number of later civil rights activists from around the world, ... Mohandas Karamchand Gandhi was leader of India's nonviolent independence movement against British rule. He was revered the world over for ... Gandhi adopted the term “civil disobedience” to describe his strategy of non-violently refusing to cooperate with injustice. Gandhi is, therefore, now a source of inspiration and a reference book for all those fighting against racial discrimination, oppression, domination, wars, ...
#
# reviewer:	**Review of Findings:**
#
# 1. **Factual Accuracy:**
#    - The inclusion of civil rights leaders such as Martin Luther King Jr., Ralph Abernathy, and others as influenced by Gandhi is accurate.
#    - The honorific "Mahātmā" and its meaning are correctly noted.
#
# 2. **Clarity and Coherence:**
#    - While the content contains relevant points about Gandhi's influence, it lacks a coherent structure and flow, making it challenging to comprehend fully.
#    - Sentences appear disjointed, and the transition between thoughts is abrupt.
#
# 3. **Relevance to the Topic:**
#    - The information provided is significantly relevant to Gandhi’s impact both on Indian independence and global civil rights movements.
#
# 4. **Proper Sourcing and Attribution:**
#    - Reference to Gandhi’s autobiography ("The Story of My Experiments with Truth") should be included for authenticity.
#    - Citing specific works or sources that discuss Gandhi’s impact on the civil rights movements would enhance credibility.
#
# **Constructive Feedback:**
# - **Organize Content:** Segment the biography to highlight Gandhi’s role in the independence movement, his philosophy, and his global influence on civil rights. Each area should have its own subsection for clarity.
#
# - **Improve Transitions:** Ensure smooth transitions between sentences and ideas to enhance readability.
#
# - **Sourcing:** Clearly cite Gandhi's autobiography and include references for the civil rights activists influenced by him. For example, refer to academic texts that analyze Gandhi's impact on figures like Martin Luther King Jr.
#
# - **Clarify Concepts:** Provide brief explanations of key concepts such as "civil disobedience" and "nonviolence" to help readers unfamiliar with these terms understand their significance.
#
# **Revised Biography Suggestion:**
#
# **Mahatma Gandhi: A Short Biography**
#
# Mahatma Gandhi, born Mohandas Karamchand Gandhi on October 2, 1869, in Porbandar, India, was a pivotal figure in the Indian independence movement against British colonial rule. As a lawyer trained in London, he initially encountered the injustice of racism in South Africa, where he began to formulate his philosophy of nonviolent resistance, which he termed *Satyagraha*.
#
# Returning to India, Gandhi became the leader of a mass movement that employed nonviolent civil disobedience to challenge British authority. His methodology drew global attention, most famously during the 1930 Salt March, where he led thousands of Indians in defiance of oppressive salt laws. His unwavering commitment to justice without violence became a testament to the power of peaceful protest.
#
# The honorific Mahātmā, meaning "great-souled" or "venerable," was first applied to him, reflecting the deep respect he garnered. Gandhi's influence extended beyond India; his philosophies inspired numerous leaders of the civil rights movement, including Martin Luther King Jr., Ralph Abernathy, and Marian Wright Edelman, among others. His teachings on inclusivity, equality, and nonviolent resistance played crucial roles in the struggle for civil rights and social justice worldwide.
#
# Gandhi's autobiography, "The Story of My Experiments with Truth," provides insight into his thoughts and methods, solidifying him as a reference for those engaged in the fight against oppression and inequality. Sadly, Gandhi's life was cut short when he was assassinated on January 30, 1948, yet his legacy as an advocate for nonviolence and justice continues to inspire generations across the globe.
#
# **Next Steps:**
# - Please refine the biography based on the feedback and make necessary changes. After confirming the adjustments, I will re-evaluate the final output for approval.
#
# researcher:	[FunctionCall(id='call_NiZkI176d3PXmLLPLcCxIX2X', arguments='{"query":"Mahatma Gandhi influence on Martin Luther King Jr."}', name='internet_search')]
#
# researcher:	[FunctionExecutionResult(content='However, King learned about Gandhi through his writings and a trip to India in 1959. He drew heavily on the Gandhian idea of nonviolence in his own activism. King wrote that Gandhi was a "guiding light" for him.', name='internet_search', call_id='call_NiZkI176d3PXmLLPLcCxIX2X', is_error=False)]
#
# researcher:	However, King learned about Gandhi through his writings and a trip to India in 1959. He drew heavily on the Gandhian idea of nonviolence in his own activism. King wrote that Gandhi was a "guiding light" for him.
#
# # Summary Document: Biography of Mahatma Gandhi
#
# ## Introduction
# This document consolidates the research process undertaken to produce a concise biography of Mahatma Gandhi, detailing his life, philosophies, and global influence, particularly in the context of civil rights.
#
# ## Research Process
# 1. **Initial Query:**
#    - The researcher initiated a search for a biography of Mahatma Gandhi, focusing on major life events, key contributions, and philosophical standpoints.
#
# 2. **Compilation of Information:**
#    - **Key findings:**
#      - Mahatma Gandhi was born Mohandas Karamchand Gandhi on October 2, 1869, in Porbandar, India.
#      - He became a key figure in the Indian independence movement against British rule.
#      - His philosophy of nonviolent resistance, termed *Satyagraha*, significantly influenced various civil rights movements globally.
#
# ## Feedback & Revisions
# ### Reviewer Feedback
# 1. **Factual Accuracy:**
#    - Confirmed the accuracy of Gandhi's full name, important dates, and contributions to independence.
#
# 2. **Clarity and Coherence:**
#    - Noted issues with fragmented structure and repetition of information; suggested reorganizing content.
#
# 3. **Relevance to the Topic:**
#    - While most provided information was relevant, redundancy detracted from impact.
#
# 4. **Proper Sourcing and Attribution:**
#    - Suggested including references like Gandhi’s autobiography for enhanced credibility.
#
# ### Constructive Improvements
# - **Organization:** Suggested structuring the biography into sections: Early Life, Career, Philosophies, and Legacy.
# - **Redundancy:** Recommended removal of repetitive statements and consolidation of ideas for a coherent narrative.
# - **Sourcing:** Advised citing Gandhi's own writings and recognized biographies to substantiate claims.
# - **Expansion:** Included comprehensive accounts of key events (e.g., the Salt March) and philosophical ideologies.
#
# ## Final Output
# ### Mahatma Gandhi: A Short Biography
# Mahatma Gandhi, born Mohandas Karamchand Gandhi on October 2, 1869, in Porbandar, India, was a pivotal figure in the Indian independence movement against British colonial rule. As a lawyer trained in London, he initially encountered the injustice of racism in South Africa, where he began to formulate his philosophy of nonviolent resistance, which he termed *Satyagraha*.
#
# Returning to India, Gandhi became the leader of a mass movement that employed nonviolent civil disobedience to challenge British authority. His methodology drew global attention, most famously during the 1930 Salt March, where he led thousands of Indians in defiance of oppressive salt laws. His unwavering commitment to justice without violence became a testament to the power of peaceful protest.
#
# The honorific Mahātmā, meaning "great-souled" or "venerable," was first applied to him, reflecting the deep respect he garnered. Gandhi's influence extended beyond India; his philosophies inspired numerous leaders of the civil rights movement, including Martin Luther King Jr., Ralph Abernathy, and Marian Wright Edelman, among others. His teachings on inclusivity and equality played crucial roles in the struggle for civil rights and social justice worldwide.
#
# Gandhi's autobiography, "The Story of My Experiments with Truth," provides insight into his thoughts and methods, solidifying him as a reference for those engaged in the fight against oppression and inequality. Tragically, his life was cut short when he was assassinated on January 30, 1948; however, his legacy as an advocate for nonviolence and justice continues to inspire generations across the globe.
#
# ## Conclusion
# This document encompasses the comprehensive research and feedback process that led to the crafting of a refined biography of Mahatma Gandhi. Further revisions, if any, can be incorporated based on new findings or additional inputs for subsequent evaluations.
